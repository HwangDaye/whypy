# %%
print('Hello')
# Out:
# Hello

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/colab_folder/whypy
# Out:
# /content/drive/MyDrive/colab_folder/whypy

# %%
# !git config --global user.email 'duidui828@gmail.com'
# !git config --global user.name 'HwangDaye'

# %%
# !git add Until.ipynb
